# %% [markdown]
# ## L1 正则 L2 正则
# ![image.png](attachment:image.png)

# %% [markdown]
# 简单的记忆
# - p = 1 L1正则
# - P = 2,不过没有根号 L2正则

# %% [markdown]
# ### LP范数与明可夫斯基距离
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 弹性网
# 在损失函数中,同时考虑了L1 L2
# ![image.png](attachment:image.png)
